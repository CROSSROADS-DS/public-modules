# %% [markdown]
# # CS120 Exercises
#
# Edit and run every code cell. Your changes are saved in this browser by JupyterLite.
#
# ## 0. Environment check

# %%
course = "CS120"
print(f"{course} notebook is ready.")

# %% [markdown]
# ## 1. Variables and expressions
#
# Set `width` and `height` to numeric values, then calculate the rectangle area.

# %%
width = 8
height = 5

# TODO: calculate width * height.
area = None

print("Area:", area)

# %% [markdown]
# ## 2. Write a conversion function
#
# Complete `fahrenheit_to_celsius`. The formula is `(F - 32) * 5 / 9`.

# %%
def fahrenheit_to_celsius(temperature_f):
    # TODO: replace None with the conversion formula.
    return None

for temperature in [32, 68, 86]:
    print(temperature, "F ->", fahrenheit_to_celsius(temperature), "C")

# %% [markdown]
# ## 3. Count vowels
#
# Complete the function so it returns the number of vowels in a string. Treat uppercase and lowercase vowels equally.

# %%
def count_vowels(text):
    vowels = "aeiou"
    count = 0

    # TODO: loop over text.lower() and update count.

    return count

print(count_vowels("Programming"))  # Expected: 3

# %% [markdown]
# ## 4. List transformation
#
# Create a new list containing the square of every number in `values`. Try both a loop and a list comprehension.

# %%
values = [1, 2, 3, 4, 5]

# TODO: replace the empty list.
squares = []

print(squares)  # Expected: [1, 4, 9, 16, 25]

# %% [markdown]
# ## 5. Challenge: word frequencies
#
# Build a dictionary that maps each normalized word to the number of times it occurs.

# %%
sentence = "Data and code and more data"
frequencies = {}

# TODO:
# 1. Convert sentence to lowercase.
# 2. Split it into words.
# 3. Update frequencies for each word.

print(frequencies)

# %% [markdown]
# ## Reflection
#
# Add a Markdown cell below and explain which exercise was most difficult and why.
